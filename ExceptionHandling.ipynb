# %% [markdown]
# <a href="https://colab.research.google.com/github/dnshirf4n/AI-Machine-Learning/blob/main/ExceptionHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exception handling in Python is a mechanism that allows you to handle runtime errors,
# or exceptions, in a controlled way, rather than letting your program crash unexpectedly.
# Python provides a way to catch errors, respond to them, and allow your program to continue
# running smoothly even if something goes wrong.

# try except finally
# try : keep that block of code inside try , which might give you an error
# except : catch that error

# %%
try:
    val1 = int(input('Enter First Value : '))
    val2 = int(input('Enter Second Value : '))
    res = val1/val2
    print(f'After Division Result Will Be {res:.2f}')
except:
    print('Something Goes Wrong....')
    print('Make Sure To Provide Only Integer Input or Second Value Can\'t Be Zero')
print('Rest Of The Code')
# Out:
# Enter First Value : 100
# Enter Second Value : 23
# After Division Result Will Be 4.35
# Rest Of The Code

# %%
# Using An Exception Class
# if you need to know the exact reason for an error use Exception class

try:
    val1 = int(input('Enter First Value : '))
    val2 = int(input('Enter Second Value : '))
    res = val1/val2
    print(f'After Division Result Will Be {res:.2f}')
except Exception as e:
    print('Something Goes Wrong....')
    print('Error :',e)
print('Rest Of The Code')
# Out:
# Enter First Value : 5
# Enter Second Value : 34
# After Division Result Will Be 0.15
# Rest Of The Code

# %%
# Using the dedicated Exception Class
try:
    val1 = int(input('Enter First Value : '))
    val2 = int(input('Enter Second Value : '))
    res = val1/val2
    print(f'After Division Result Will Be {res:.2f}')
except (ZeroDivisionError,ValueError) as e:
    print('Something Goes Wrong....')
    print('Error :',e)
print('Rest Of The Code')

# %%
# finally
# finally execute always

# Case No. 1 : WHEN THERE IS NO EXCEPTION

try:
    val1 = int(input('Enter First Value : '))
    val2 = int(input('Enter Second Value : '))
    res = val1/val2
    print(f'After Division Result Will Be {res:.2f}')
except Exception as e:
    print('Something Goes Wrong....')
    print('Error :',e)
finally:
    print('I WILL EXECUTE ALWAYS 😎')
print('Rest Of The Code')

# %%
# Case No. 2 : WHEN THERE IS AN EXCEPTION

try:
    val1 = int(input('Enter First Value : '))
    val2 = int(input('Enter Second Value : '))
    res = val1/val2
    print(f'After Division Result Will Be {res:.2f}')
except Exception as e:
    print('Something Goes Wrong....')
    print('Error :',e)
finally:
    print('I WILL EXECUTE ALWAYS 😎')
print('Rest Of The Code')

# %%
# Case No. 3 : WHEN THERE IS AN EXCEPTION BUT NOT HANDELLED PROPERLY

try:
    val1 = int(input('Enter First Value : '))
    val2 = int(input('Enter Second Value : '))
    res = val1/val2
    print(f'After Division Result Will Be {res:.2f}')
except ImportError as e:
    print('Something Goes Wrong....')
    print('Error :',e)
finally:
    print('I WILL EXECUTE ALWAYS 😎')
print('Rest Of The Code')
